# %%
import numpy as np
import pandas as pd
import datetime
from scipy.stats import uniform, randint
import math
from sklearn.datasets import load_breast_cancer, load_diabetes, load_wine
from sklearn.metrics import auc, accuracy_score, confusion_matrix, mean_squared_error
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold, RandomizedSearchCV, train_test_split,StratifiedKFold

import xgboost as xgb

# %%
#-----------------READ DATA----------------
datafilename = 'DATA/MockDATA_10percent.csv'

Data = pd.read_csv(datafilename)[['date','exdate','delta','impl_volatility',"cp_flag"]] #try using more features later
Data['date'] = pd.to_datetime(Data['date'])
Data['exdate'] = pd.to_datetime(Data['exdate'])


#sdate = datetime.datetime(2019,4,13)
#edate = datetime.datetime(2019,4,20)


#Data = Data[Data['date'] < edate] #change this line if we need more complicated set of data
#Data = Data[Data['date'] >= sdate]

Data['time_to_maturity'] = (Data['exdate']-Data['date']).astype('int64')/10**9/3600/24
Data = Data.dropna()

Data
Data = Data.dropna()

Data = Data.sort_values(by='date')
Data['impl_volatility'] = np.log(Data['impl_volatility'])

Data = Data[Data["cp_flag"] == "C"]
print(Data)
# Out:
#               date     exdate     delta  impl_volatility cp_flag
# 0       2018-02-28 2018-09-21  0.776262        -1.510561       C  \
# 780     2018-02-28 2018-06-29  0.169746        -2.120272       C
# 785     2018-02-28 2018-06-29  0.662646        -1.669820       C
# 788     2018-02-28 2018-12-21  0.973789        -0.814296       C
# 791     2018-02-28 2018-04-20  0.951787        -0.809045       C
# ...            ...        ...       ...              ...     ...
# 2133073 2023-02-28 2023-03-27  0.459562        -1.640929       C
# 2113668 2023-02-28 2023-04-21  0.300511        -1.777419       C
# 2133100 2023-02-28 2023-03-15  0.830740        -1.381148       C
# 2114552 2023-02-28 2024-01-19  0.905867        -1.186254       C
# 2118538 2023-02-28 2023-05-31  0.932871        -1.091079       C
#
#          time_to_maturity
# 0                   205.0
# 780                 121.0
# 785                 121.0
# 788                 296.0
# 791                  51.0
# ...                   ...
# 2133073              27.0
# 2113668              52.0
# 2133100              15.0
# 2114552             325.0
# 2118538              92.0
#
# [937062 rows x 6 columns]

# %%
#Train Test Split

rate = 0.2
rows, columns = Data.shape
num = round(rows*(1-rate))

idx = Data.index
train = Data.loc[idx[0:num]]
test = Data.loc[idx[num:]]



X_train = train[['delta','time_to_maturity']]
X_test = test[['delta','time_to_maturity']]

y_train = train['impl_volatility']
y_test = test['impl_volatility']

# %%
XGBR = xgb.XGBRegressor()

#Hyper parameter tuning
#brute force grid search 

pgrid = {
    'n_estimators': [5,10,50,75,100],
    'eta': [0.01,0.1],
    'subsample': [0.2,0.5,0.8,1],
    'colsample_bytree': [0.2,0.5,0.8,1],
    'max_depth':[2,5,10,15]
        }

grid_search = GridSearchCV(estimator=XGBR, param_grid=pgrid, scoring='neg_mean_squared_error',n_jobs = 4,cv=5, verbose=3 )
grid_search.fit(X_train,y_train)

bestxgbr = grid_search.best_estimator_
print(grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 640 candidates, totalling 3200 fits
# [CV 3/5] END colsample_bytree=0.2, eta=0.01, max_depth=2, n_estimators=5, subsample=0.2;, score=-0.379 total time=   0.2s
# [CV 1/5] END colsample_bytree=0.2, eta=0.01, max_depth=2, n_estimators=5, subsample=0.5;, score=-0.365 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.2, eta=0.01, max_depth=2, n_estimators=5, subsample=0.5;, score=-0.272 total time=   0.2s
# [CV 1/5] END colsample_bytree=0.2, eta=0.01, max_depth=2, n_estimators=5, subsample=1;, score=-0.365 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.2, eta=0.01, max_depth=2, n_estimators=5, subsample=1;, score=-0.379 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.2, eta=0.01, max_depth=2, n_estimators=10, subsample=0.2;, score=-0.349 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.2, eta=0.01, max_depth=2, n_estimators=10, subsample=0.5;, score=-0.348 total time=   0.3s
# [CV 2/5] END colsample_bytree=0.2, eta=0.01, max_depth=2, n_estimators
total time=   0.3s
# [CV 1/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=10, subsample=1;, score=-0.358 total time=   0.3s
# [CV 5/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=10, subsample=1;, score=-0.266 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.2, eta=0.01, max_depth=2, n_estimators=75, subsample=1;, score=-0.324 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.2, eta=0.01, max_depth=2, n_estimators=100, subsample=0.2;, score=-0.312 total time=   0.7s
# [CV 1/5] END colsample_bytree=0.2, eta=0.01, max_depth=2, n_estimators=100, subsample=0.5;, score=-0.259 total time=   0.8s
# [CV 5/5] END colsample_bytree=0.2, eta=0.01, max_depth=2, n_estimators=100, subsample=0.5;, score=-0.171 total time=   0.8s
# [CV 4/5] END colsample_bytree=0.2, eta=0.01, max_depth=2, n_estimators=100, subsample=0.8;, score=-0.231 total time=   0.7s
# [CV 3/5] END colsample_bytree=0.2, eta=0.01, max_depth=2, n_estimators=100, subsample=1;, score=-0.312 total time=   0.6s
# [CV 1/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=5, subsample=0.2;, score=-0.363 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=5, subsample=0.2;, score=-0.377 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=5, subsample=0.2;, score=-0.270 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=5, subsample=0.5;, score=-0.377 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=5, subsample=0.8;, score=-0.351 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=5, subsample=0.8;, score=-0.270 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=5, subsample=1;, score=-0.270 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=10, subsample=0.2;, score=-0.349 total time=   0.3s
# [CV 2/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=10, subsample=0.5;, score=-0.346 total time=   0.3s
# [CV 1/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=10, subsample=0.8;, score=-0.357 total time=   0.3s
# [CV 5/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=10, subsample=0.8;, score=-0.266 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=10, subsample=1;, score=-0.349 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=50, subsample=0.2;, score=-0.325 total time=   0.8s
# [CV 2/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=50, subsample=0.5;, score=-0.272 total time=   0.8s
# [CV 1/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=50, subsample=0.8;, score=-0.284 total time=   0.7s
# [CV 5/5] END colsample_bytree=0.2, eta=0.01, max_depth=2, n_estimators=75, subsample=0.8;, score=-0.192 total time=   0.8s
# [CV 1/5] END colsample_bytree=0.2, eta=0.01, max_depth=2, n_estimators=100, subsample=0.2;, score=-0.259 total time=   0.8s
# [CV 5/5] END colsample_bytree=0.2, eta=0.01, max_depth=2, n_estimators=100, subsample=0.2;, score=-0.172 total time=   0.9s
# [CV 4/5] END colsample_bytree=0.2, eta=0.01, max_depth=2, n_estimators=100, subsample=0.5;, score=-0.231 total time=   1.0s
# [CV 3/5] END colsample_bytree=0.2, eta=0.01, max_depth=2, n_estimators=100, subsample=0.8;, score=-0.312 total time=   0.8s
# [CV 2/5] END colsample_bytree=0.2, eta=0.01, max_depth=2, n_estimators=100, subsample=1;, score=-0.244 total time=   0.6s
# [CV 4/5] END colsample_bytree=0.2, eta=0.01, max_depth=2, n_estimators=100, subsample=1;, score=-0.231 total time=   0.6s
# [CV 1/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=5, subsample=0.5;, score=-0.363 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=5, subsample=0.5;, score=-0.270 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=5, subsample=0.8;, score=-0.354 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=5, subsample=1;, score=-0.377 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=10, subsample=0.2;, score=-0.346 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=10, subsample=0.2;, score=-0.266 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=10, subsample=0.5;, score=-0.349 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=10, subsample=0.8;, score=-0.373 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=10, subsample=1;, score=-0.346 total time=   0.2s
# [CV 1/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=50, subsample=0.2;, score=-0.284 total time=   0.7s
# [CV 5/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=50, subsample=0.2;, score=-0.195 total time=   0.7s
# [CV 3/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=50, subsample=0.5;, score=-0.325 total time=   0.9s
# [CV 3/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=50, subsample=0.8;, score=-0.326 total time=   0.9s
# [CV 3/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=50, subsample=1;, score=-0.326 total time=   0.6s
# [CV 1/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=75, subsample=0.2;, score=-0.263 total time=   0.9s
# [CV 4/5] END colsample_bytree=0.2, eta=0.01, max_depth=2, n_estimators=75, subsample=1;, score=-0.257 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.2, eta=0.01, max_depth=2, n_estimators=100, subsample=0.2;, score=-0.231 total time=   0.9s
# [CV 3/5] END colsample_bytree=0.2, eta=0.01, max_depth=2, n_estimators=100, subsample=0.5;, score=-0.312 total time=   1.0s
# [CV 2/5] END colsample_bytree=0.2, eta=0.01, max_depth=2, n_estimators=100, subsample=0.8;, score=-0.244 total time=   0.9s
# [CV 1/5] END colsample_bytree=0.2, eta=0.01, max_depth=2, n_estimators=100, subsample=1;, score=-0.259 total time=   0.8s
# [CV 2/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=5, subsample=0.2;, score=-0.351 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=5, subsample=0.2;, score=-0.354 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=5, subsample=0.5;, score=-0.351 total time=   0.2s
# [CV 1/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=5, subsample=0.8;, score=-0.363 total time=   0.2s
# [CV 1/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=5, subsample=1;, score=-0.363 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=5, subsample=1;, score=-0.354 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=10, subsample=0.2;, score=-0.374 total time=   0.3s
# [CV 1/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=10, subsample=0.5;, score=-0.357 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=10, subsample=0.5;, score=-0.266 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=10, subsample=0.8;, score=-0.349 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=10, subsample=1;, score=-0.373 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=50, subsample=0.2;, score=-0.272 total time=   0.8s
# [CV 1/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=50, subsample=0.5;, score=-0.284 total time=   0.8s
# [CV 4/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=50, subsample=0.5;, score=-0.264 total time=   1.0s
# [CV 5/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=50, subsample=0.8;, score=-0.195 total time=   0.6s
# [CV 2/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=50, subsample=1;, score=-0.272 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=50, subsample=1;, score=-0.264 total time=   0.6s
# [CV 3/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=75, subsample=0.2;, score=-0.313 total time=   0.9s
# [CV 4/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=50, subsample=0.2;, score=-0.264 total time=   0.7s
# [CV 5/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=50, subsample=0.5;, score=-0.195 total time=   0.7s
# [CV 2/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=50, subsample=0.8;, score=-0.272 total time=   0.7s
# [CV 1/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=50, subsample=1;, score=-0.284 total time=   0.8s
# [CV 2/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=75, subsample=0.2;, score=-0.251 total time=   1.3s
# [CV 1/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=75, subsample=0.5;, score=-0.263 total time=   1.0s
# [CV 4/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=75, subsample=0.5;, score=-0.241 total time=   1.2s
# [CV 3/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=75, subsample=0.8;, score=-0.313 total time=   1.2s
# [CV 4/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=75, subsample=1;, score=-0.241 total time=   1.0s
# [CV 3/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=100, subsample=0.2;, score=-0.301 total time=   1.1s
# [CV 1/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=100, subsample=0.5;, score=-0.240 total time=   1.7s
# [CV 5/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=100, subsample=0.5;, score=-0.154 total time=   1.3s
# [CV 4/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=100, subsample=0.8;, score=-0.213 total time=   1.2s
# [CV 3/5] END colsample_bytree=0.2, eta=0.01, max_depth=5, n_estimators=100, subsample=1;, score=-0.301 total time=   1.5s
# [CV 1/5] END colsample_bytree=0.2, eta=0.01, max_depth=10, n_estimators
total time=   0.3s
# [CV 1/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=10, subsample=0.2;, score=-0.357 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=10, subsample=0.5;, score=-0.357 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=10, subsample=0.8;, score=-0.357 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=10, subsample=0.8;, score=-0.349 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=10, subsample=1;, score=-0.373 total time=   0.3s
# [CV 1/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=50, subsample=0.2;, score=-0.283 total time=   1.2s
# [CV 5/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=50, subsample=0.2;, score=-0.195 total time=   1.5s
# [CV 4/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=50, subsample=0.5;, score=-0.264 total time=   1.4s
# [CV 3/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=50, subsample=0.8;, score=-0.325 total time=   1.5s
# [CV 3/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=50, subsample=1;, score=-0.325 total time=   1.1s
# [CV 3/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=10, subsample=0.2;, score=-0.373 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=10, subsample=0.5;, score=-0.265 total time=   0.3s
# [CV 2/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=10, subsample=0.8;, score=-0.346 total time=   0.3s
# [CV 1/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=10, subsample=1;, score=-0.357 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=10, subsample=1;, score=-0.349 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=50, subsample=0.2;, score=-0.325 total time=   1.5s
# [CV 2/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=50, subsample=0.5;, score=-0.271 total time=   1.4s
# [CV 1/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=50, subsample=0.8;, score=-0.283 total time=   1.9s
# [CV 1/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=50, subsample=1;, score=-0.283 total time=   1.2s
# [CV 5/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=50, subsample=1;, score=-0.195 total time=   1.4s
# [CV 4/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=75, subsample=0.2;, score=-0.241 total time=   2.0s
# [CV 2/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=75, subsample=0.5;, score=-0.250 total time=   2.1s
# [CV 1/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=75, subsample=0.8;, score=-0.262 total time=   4.2s
# [CV 5/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=75, subsample=0.8;, score=-0.176 total time=   4.5s
# [CV 4/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=75, subsample=1;, score=-0.241 total time=   3.9s
# [CV 3/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=100, subsample=0.2;, score=-0.301 total time=   6.0s
# [CV 2/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=100, subsample=0.5;, score=-0.227 total time=   4.8s
# [CV 5/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=100, subsample=0.5;, score=-0.154 total time=   5.6s
# [CV 4/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=100, subsample=0.8;, score=-0.212 total time=   4.7s
# [CV 2/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=100, subsample=1;, score=-0.227 total time=   4.5s
# [CV 1/5] END colsample_bytree=0.2, eta=0.1, max_depth=2, n_estimators=5, subsample=0.2;, score=-0.295 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.2, eta=0.1, max_depth=2, n_estimators=5, subsample=0.2;, score=-0.334 total time=   0.3s
# [CV 5/5] END colsample_bytree=0.2, eta=0.1, max_depth=2, n_estimators=5, subsample=0.2;, score=-0.205 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.2, eta=0.1, max_depth=2, n_estimators=5, subsample=0.5;, score=-0.333 total time=   0.3s
# [CV 1/5] END colsample_bytree=0.2, eta=0.1, max_depth=2, n_estimators=5, subsample=0.8;, score=-0.295 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.2, eta=0.1, max_depth=2, n_estimators=5, subsample=0.8;, score=-0.274 total time=   0.3s
# [CV 1/5] END colsample_bytree=0.2, eta=0.1, max_depth=2, n_estimators=5, subsample=1;, score=-0.295 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.2, eta=0.1, max_depth=2, n_estimators=5, subsample=1;, score=-0.205 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.2, eta=0.1, max_depth=2, n_estimators=10, subsample=0.2;, score=-0.318 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.2, eta=0.1, max_depth=2, n_estimators=10, subsample=0.5;, score=-0.319 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.2, eta=0.1, max_depth=2, n_estimators=10, subsample=0.8;, score=-0.256 total time=   0.3s
# [CV 2/5] END colsample_bytree=0.2, eta=0.1, max_depth=2, n_estimators=10, subsample=1;, score=-0.257 total time=   0.2s
# [CV 1/5] END colsample_bytree=0.2, eta=0.1, max_depth=2, n_estimators=50, subsample=0.2;, score=-0.176 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.2, eta=0.1, max_depth=2, n_estimators=50, subsample=0.5;, score=-0.176 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.2, eta=0.01, max_depth=10, n_estimators=100, subsample=1;, score=-0.212 total time=   1.8s
# [CV 1/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=5, subsample=0.8;, score=-0.362 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=5, subsample=0.8;, score=-0.270 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=5, subsample=1;, score=-0.354 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=10, subsample=0.2;, score=-0.346 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=10, subsample=0.2;, score=-0.265 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=10, subsample=0.5;, score=-0.373 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=10, subsample=0.8;, score=-0.373 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=10, subsample=1;, score=-0.346 total time=   0.3s
# [CV 5/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=10, subsample=1;, score=-0.265 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=50, subsample=0.2;, score=-0.264 total time=   1.1s
# [CV 1/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=50, subsample=0.5;, score=-0.283 total time=   1.4s
# [CV 5/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=50, subsample=0.5;, score=-0.195 total time=   1.4s
# [CV 4/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators=50, subsample=0.8;, score=-0.264 total time=   1.4s
# [CV 2/5] END colsample_bytree=0.2, eta=0.01, max_depth=15, n_estimators

# [CV 1/5] END colsample_bytree=1, eta=0.1, max_depth=15, n_estimators=75, subsample=0.5;, score=-0.172 total time=   4.9s
# [CV 2/5] END colsample_bytree=1, eta=0.1, max_depth=15, n_estimators=75, subsample=0.8;, score=-0.160 total time=   3.5s
# [CV 5/5] END colsample_bytree=1, eta=0.1, max_depth=15, n_estimators=75, subsample=0.8;, score=-0.081 total time=   3.6s
# [CV 3/5] END colsample_bytree=1, eta=0.1, max_depth=15, n_estimators=75, subsample=1;, score=-0.315 total time=   3.7s
# [CV 4/5] END colsample_bytree=1, eta=0.1, max_depth=15, n_estimators=75, subsample=0.8;, score=-0.098 total time=   3.9s
# [CV 4/5] END colsample_bytree=1, eta=0.1, max_depth=15, n_estimators=75, subsample=1;, score=-0.098 total time=   3.5s
# [CV 1/5] END colsample_bytree=1, eta=0.1, max_depth=15, n_estimators=100, subsample=0.2;, score=-0.173 total time=   4.5s
# [CV 5/5] END colsample_bytree=1, eta=0.1, max_depth=15, n_estimators=100, subsample=0.2;, score=-0.081 total time=   4.7s
# [CV 2/5] END colsample_bytree=1, eta=0.1, max_depth=15, n_estimators=100, subsample=0.2;, score=-0.161 total time=   6.0s
# [CV 2/5] END colsample_bytree=1, eta=0.1, max_depth=15, n_estimators=100, subsample=0.5;, score=-0.161 total time=   5.2s
# [CV 2/5] END colsample_bytree=1, eta=0.1, max_depth=15, n_estimators=100, subsample=0.8;, score=-0.161 total time=   5.0s
# [CV 2/5] END colsample_bytree=1, eta=0.1, max_depth=15, n_estimators=75, subsample=1;, score=-0.160 total time=   5.8s
# [CV 3/5] END colsample_bytree=1, eta=0.1, max_depth=15, n_estimators=100, subsample=0.2;, score=-0.315 total time=   4.7s
# [CV 1/5] END colsample_bytree=1, eta=0.1, max_depth=15, n_estimators=100, subsample=0.5;, score=-0.173 total time=   5.1s
# [CV 5/5] END colsample_bytree=1, eta=0.1, max_depth=15, n_estimators=100, subsample=0.5;, score=-0.081 total time=   5.0s
# [CV 4/5] END colsample_bytree=1, eta=0.1, max_depth=15, n_estimators=100, subsample=0.8;, score=-0.099 total time=   5.2s
# [CV 1/5] END colsample_bytree=1, eta=0.1, max_depth=15, n_estimators=75, subsample=1;, score=-0.172 total time=   4.4s
# [CV 5/5] END colsample_bytree=1, eta=0.1, max_depth=15, n_estimators=75, subsample=1;, score=-0.080 total time=   3.7s
# [CV 4/5] END colsample_bytree=1, eta=0.1, max_depth=15, n_estimators=100, subsample=0.2;, score=-0.099 total time=   4.6s
# [CV 3/5] END colsample_bytree=1, eta=0.1, max_depth=15, n_estimators=100, subsample=0.5;, score=-0.315 total time=   5.0s
# [CV 1/5] END colsample_bytree=1, eta=0.1, max_depth=15, n_estimators=100, subsample=0.8;, score=-0.173 total time=   5.5s
# [CV 1/5] END colsample_bytree=1, eta=0.1, max_depth=15, n_estimators=100, subsample=1;, score=-0.172 total time=   5.0s
# {'colsample_bytree': 1, 'eta': 0.1, 'max_depth': 5, 'n_estimators': 50, 'subsample': 0.2}
# [CV 5/5] END colsample_bytree=1, eta=0.1, max_depth=15, n_estimators=100, subsample=0.8;, score=-0.081 total time=   5.2s
# [CV 5/5] END colsample_bytree=1, eta=0.1, max_depth=15, n_estimators=100, subsample=1;, score=-0.081 total time=   4.7s
# [CV 3/5] END colsample_bytree=1, eta=0.1, max_depth=15, n_estimators=100, subsample=1;, score=-0.315 total time=   5.0s
# [CV 4/5] END colsample_bytree=1, eta=0.1, max_depth=15, n_estimators=100, subsample=1;, score=-0.098 total time=   4.7s

# %%
#fitting on the training set

y_p_xgbr = bestxgbr.predict(X_test)

goodness = mean_squared_error(y_p_xgbr,y_test)

print(goodness)
print(grid_search.best_params_)
# Out:
# 0.08618972208865966
# {'colsample_bytree': 1, 'eta': 0.1, 'max_depth': 5, 'n_estimators': 50, 'subsample': 0.2}

# %%
from matplotlib import interactive

import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
#Plot the fitting result
interactive(True)
#delta = 0.1, 0., 15, 0.2, 0.25, 0.3, 0.35, . . . , 0.9
#time to expiry of 1, 2, 3, 4, 8, 12, 18, 52, 104 weeks. 
D = np.linspace(-1, 1, 41, endpoint=True)
T = np.array([1,2,3,4,8,12,18,52,104,156])
T_days = T*7 #over time_to_maturity is in days

dd,tt = np.meshgrid(D,T_days)


X_plot = np.array([dd.flatten(), tt.flatten()]).T

y_plot = bestxgbr.predict(X_plot)

z = y_plot.reshape(dd.shape)

# %%
xd_test = np.array(X_test['delta'])
xt_test = np.array(X_test['time_to_maturity'])

test_z = np.array(y_test)


xd_train = np.array(X_train['delta'])
xt_train = np.array(X_train['time_to_maturity'])

train_z = np.array(y_train)

# %%
# %matplotlib qt 
fig = plt.figure()
ax = Axes3D(fig)

ax.plot_surface(dd,tt, z,cmap =cm.coolwarm)


#ax.scatter(xd_train, xt_train, train_z, color='green')
ax.scatter(xd_test, xt_test, test_z, color='red')

ax.set_xlabel('delta')
ax.set_ylabel('time to maturity')
ax.set_zlabel('Volatility');

plt.show()
# Out:
# [CV 4/5] END colsample_bytree=1, eta=0.1, max_depth=15, n_estimators=100, subsample=0.5;, score=-0.098 total time=   6.1s
# [CV 3/5] END colsample_bytree=1, eta=0.1, max_depth=15, n_estimators=100, subsample=0.8;, score=-0.315 total time=   5.7s
# [CV 2/5] END colsample_bytree=1, eta=0.1, max_depth=15, n_estimators=100, subsample=1;, score=-0.161 total time=   5.5s
